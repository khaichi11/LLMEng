# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
openai = OpenAI()

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
MODEL_GPT = "gpt-4.1-mini"
MODEL_LLAMA = "llama3.2"

# %%
question = """
Apa perbedaan list, set, dan tuple dalam Python?
Jawab dalam teks biasa tanpa markdown, tanpa heading, dan tanpa tabel.
"""

# %%
pesan = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=pesan,
)

# %%
response.choices[0].message.content
# Out:
# 'List, set, dan tuple adalah tipe data di Python yang digunakan untuk menyimpan kumpulan elemen, tetapi memiliki beberapa perbedaan utama. List adalah kumpulan yang terurut (ordered) dan dapat diubah (mutable), sehingga elemen-elemen di dalamnya bisa diakses berdasarkan indeks dan bisa ditambah, dihapus, atau diubah nilainya. Set adalah kumpulan yang tidak terurut (unordered) dan unik, artinya elemen-elemen di dalamnya tidak memiliki urutan tertentu dan tidak boleh ada duplikasi elemen; set juga mutable tapi karena tidak terurut, elemen tidak bisa diakses berdasarkan indeks. Tuple adalah kumpulan yang terurut seperti list, tetapi bersifat tidak dapat diubah (immutable), sehingga setelah tuple dibuat, elemen-elemennya tidak bisa diubah, ditambah, atau dihapus. Singkatnya, list mutable dan terurut, set mutable dan tidak terurut serta unik, dan tuple immutable serta terurut.'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama_client = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

response = ollama_client.chat.completions.create(
    model = MODEL_LLAMA, 
    messages = pesan
)

print(response.choices[0].message.content)
# Out:
# Dalam Python, `list`, `set`, dan `tuple` adalah tipe data berbasis struktur yang digunakan untuk menyimpan element-element dengan nilai tertentu. Berikut perbedaan antara ketiga tersebut:
#
# 1. **List (daftar)**:
#    - Dapat memiliki bilangan ulang pada indexnya.
#    - Memungkinkan digabungkan/ diubah menjadi lebih besar, dan terbuka.
#    - Selalu dapat menerima apapun sebagai elemen.
#    - Berbeda dari string karena bisa berisi tidak hanya karakter tapi apapun.
#
# 2. **Set (kolik)**:
#    - Tidak memiliki bilangan ulang pada indeksnya.
#    - Dapat diubah menjadi list atau str, tetapi bukan sebaliknyanya, melalui fungsi `set` dan `tuple`.
#    - Hanya menerima value jika sudah di dalam set. Jika ingin menambahkan, harus berupa beberapa elemen halus (`{value}`).
#    - Selalu unik.
#    Sebenarnya set tidak dapat memiliki indeks.
#
# 3. **Tuple (tupel)**:
#    - Tidak memiliki bilangan ulang pada indeksnya.
#    - Dapat diubah menjadi list atau str, tetapi bukan sebaliknyanya dengan fungsi `tuple` dan `list`.
#    - Hanya menerima value jika sudah di dalam tuple. Jika ingin menambahkan, harus berupa beberapa elemen halus (`(value)`).
#    - Selalu unik.
#    Sebenarnya tupel tidak dapat memiliki indeks.
#
# Kapan sebaiknya digunakan:
#
# - **List**: Saat Anda membutuhkan list yang dapat diakses dengan index (indek) dan dapat ditambahkan/subtrahkan item di dalamnya.
# - **Set**: Saat Anda ingin menyimpan kumpulan data angka tanpa perulangan atau berurutan, karena dapat mempercepat akses pada data dan performa sistem. Namun saat digunakan bisa sulit untuk mengakses data angka keberapa.
# - **Tuple**: Saat Anda ingin menyimpan nilai yang sudah diubah ke `list` atau memiliki nilai unik tidak boleh berulang.
